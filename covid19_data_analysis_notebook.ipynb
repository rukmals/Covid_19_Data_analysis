# %% [markdown]
# <a href="https://colab.research.google.com/github/rukmals/Covid_19_Data_analysis/blob/master/covid19_data_analysis_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Covid19 Data Analysis Notebook
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
data = pd.read_csv('/content/sample_data/covid19_Confirmed_dataset.csv')
data.head()
# Out:
#   Province/State Country/Region      Lat  ...  4/28/20  4/29/20  4/30/20
# 0            NaN    Afghanistan  33.0000  ...     1828     1939     2171
# 1            NaN        Albania  41.1533  ...      750      766      773
# 2            NaN        Algeria  28.0339  ...     3649     3848     4006
# 3            NaN        Andorra  42.5063  ...      743      743      745
# 4            NaN         Angola -11.2027  ...       27       27       27
#
# [5 rows x 104 columns]

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
data.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
#df = data.drop(["Lat","Long"],axis=1,inplace=True)

# %%
data.head()
# Out:
#   Province/State Country/Region  1/22/20  ...  4/28/20  4/29/20  4/30/20
# 0            NaN    Afghanistan        0  ...     1828     1939     2171
# 1            NaN        Albania        0  ...      750      766      773
# 2            NaN        Algeria        0  ...     3649     3848     4006
# 3            NaN        Andorra        0  ...      743      743      745
# 4            NaN         Angola        0  ...       27       27       27
#
# [5 rows x 102 columns]

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
data_aggregate = data.groupby("Country/Region").sum()

# %%
data_aggregate.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1828     1939     2171
# Albania               0        0        0  ...      750      766      773
# Algeria               0        0        0  ...     3649     3848     4006
# Andorra               0        0        0  ...      743      743      745
# Angola                0        0        0  ...       27       27       27
#
# [5 rows x 100 columns]

# %%
data_aggregate.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Task 2.4: Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
data_aggregate.loc["China"].plot()
data_aggregate.loc["Italy"].plot()
plt.legend()

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
data_aggregate.loc['China'].plot()

# %%
data_aggregate.loc['China'][:3].plot()

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
data_aggregate.loc['China'][:100].diff().plot()

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for China

# %%
data_aggregate.loc['China'][:100].diff().max()
# Out:
# 15136.0

# %%
data_aggregate.loc['Italy'][:100].diff().max()
# Out:
# 6557.0

# %%
data_aggregate.loc['Spain'][:100].diff().max()
# Out:
# 9630.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(data_aggregate.index)
maximum_infection_rate = []

for c in countries:
  maximum_infection_rate.append(data_aggregate.loc[c].diff().max())
data_aggregate["maximum_Infection_rate"] = maximum_infection_rate

# %%
data_aggregate.head()
# Out:
#                 1/22/20  1/23/20  ...  4/30/20  maximum_Infection_rate
# Country/Region                    ...
# Afghanistan           0        0  ...     2171                   232.0
# Albania               0        0  ...      773                    34.0
# Algeria               0        0  ...     4006                   199.0
# Andorra               0        0  ...      745                    43.0
# Angola                0        0  ...       27                     5.0
#
# [5 rows x 101 columns]

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
covid_data = pd.DataFrame(data_aggregate["maximum_Infection_rate"])

# %%
covid_data.head()
# Out:
#                 maximum_Infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
happy_data= pd.read_csv('/content/sample_data/worldwide_happiness_report.csv')
happy_data.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
happy_data.columns[0]
# Out:
# 'Overall rank'

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
useless_columns = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
df = pd.DataFrame()
df["Country"]=happy_data[happy_data.columns[1]]
df["GDP"] = happy_data[happy_data.columns[3]]
df["Social"] = happy_data[happy_data.columns[4]]
df["Healthy"] = happy_data[happy_data.columns[5]]
df["Freedom to make life choice"] = happy_data[happy_data.columns[6]]
df.head()
# Out:
#        Country    GDP  Social  Healthy  Freedom to make life choice
# 0      Finland  1.340   1.587    0.986                        0.596
# 1      Denmark  1.383   1.573    0.996                        0.592
# 2       Norway  1.488   1.582    1.028                        0.603
# 3      Iceland  1.380   1.624    1.026                        0.591
# 4  Netherlands  1.396   1.522    0.999                        0.557

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %%
df.head()
# Out:
#                GDP  Social  Healthy  Freedom to make life choice
# Country
# Finland      1.340   1.587    0.986                        0.596
# Denmark      1.383   1.573    0.996                        0.592
# Norway       1.488   1.582    1.028                        0.603
# Iceland      1.380   1.624    1.026                        0.591
# Netherlands  1.396   1.522    0.999                        0.557

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
covid_data.shape
# Out:
# (187, 1)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
df.head()
# Out:
#                GDP  Social  Healthy  Freedom to make life choice
# Country
# Finland      1.340   1.587    0.986                        0.596
# Denmark      1.383   1.573    0.996                        0.592
# Norway       1.488   1.582    1.028                        0.603
# Iceland      1.380   1.624    1.026                        0.591
# Netherlands  1.396   1.522    0.999                        0.557

# %%
join_data = covid_data.join(df,how="inner")

# %%
join_data.shape
# Out:
# (143, 5)

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
join_data.corr()
# Out:
#                              maximum_Infection_rate  ...  Freedom to make life choice
# maximum_Infection_rate                     1.000000  ...                     0.078196
# GDP                                        0.250118  ...                     0.394603
# Social                                     0.191958  ...                     0.456246
# Healthy                                    0.289263  ...                     0.427892
# Freedom to make life choice                0.078196  ...                     1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
join_data.head()
# Out:
#              maximum_Infection_rate  ...  Freedom to make life choice
# Afghanistan                   232.0  ...                        0.000
# Albania                        34.0  ...                        0.383
# Algeria                       199.0  ...                        0.086
# Argentina                     291.0  ...                        0.471
# Armenia                       134.0  ...                        0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x= join_data["GDP"]
y = join_data["maximum_Infection_rate"]
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate
